# %% [markdown]
# A scraper for Autobiography collection.
# Source: garamantas.lv

# %% [markdown]
# First, all links to the autobiographies were identified in the collection, using https://garamantas.lv/lv/collection/index?CollectionSearch%5Brepository_id%5D=1115628 as a base URL. Key to the autobiography links was combination of "/lv/collection/" and IDs of each collection. The result, however, will exceed the 219 autobiographies.

# %%
import requests
from bs4 import BeautifulSoup
import csv
from urllib.parse import urljoin
import re

def find_unique_collection_pages(base_url):

    response = requests.get(base_url, timeout=20)
    soup = BeautifulSoup(response.content, 'html.parser')
    collection_links = set()  # Using a set to ensure uniqueness

    for link in soup.find_all('a', href=True):
        absolute_url = urljoin(base_url, link['href'])
        if '/lv/collection/' in absolute_url:
            collection_links.add(absolute_url)

    return list(collection_links)

# Define sorting key to extract and convert digits following '/collection/' into integers
def sorting_key(link):
    match = re.search(r'/collection/(\d{7,})/', link)
    if match:
        return int(match.group(1))
    return float('inf')  # Return a very large number if no match found

def scrape_and_save_links(collection_links):
    unique_links = set()  # Set to store unique links
    for collection_link in collection_links:
        response = requests.get(collection_link, timeout=20)
        soup = BeautifulSoup(response.content, 'html.parser')
        target_links = soup.find_all('a', href=True)

        for link in target_links:
            href = link['href']
            # Check if the link matches the specified structure
            if re.match(r'/lv/collection/\d{7,}/[a-zA-Z]+', href):
                unique_links.add(href)  # Add to set to ensure uniqueness

    # Sort the unique links by the string of digits following '/collection/' in ascending order
    unique_links_sorted = sorted(unique_links, key=sorting_key)

    # Save the unique links to 'links.csv'
    with open('links.csv', 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Link'])  # Add the header row
        for link in unique_links_sorted:
            writer.writerow([link])

base_url = 'https://garamantas.lv/lv/collection/index?CollectionSearch%5Brepository_id%5D=1115628'
collection_pages = find_unique_collection_pages(base_url)
scrape_and_save_links(collection_pages)

# %% [markdown]
# More than 400 unique links are a significantly more than the actual number of 219 autobiographies, but this selection allowed to analyse the structures of the data in the repository. With a simple function it will be possible to filter the unnecessary files and reconstitute them as full URLs for each of the autobiographies.

# %%
# The code will find all unique diaries from csv file and save them to 'diaries.csv' by concatenating the base URL to string before "?", /
# and adding base URL to the beginning of each link.

import csv

infile = open('links.csv', mode = 'r', encoding = 'utf-8')
links =  infile.readlines()

infile.close()

base_url = 'https://garamantas.lv' 

links = links[1:] # removing header
for link in range(len(links)):
    if char := links[link].find('?'):
        links[link] = links[link][:char]
    else:
        continue

new_links = sorted(set(base_url + link for link in links), key=sorting_key)

with open('diaries.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Link'])
    for link in new_links:
        writer.writerow([link])

print(f"There are {len(new_links)} diaries saved to diaries.csv")

# %% [markdown]
# Next task is the finding of all verified transcripts existing for the diaries. The study of the structure indicated that the texts that have to be saved are in file-pages, which will have to be found.

# %%
# Next task is the finding of all verified transcripts existing for the diaries.
# The study of the structure indicated that the texts that have to be saved are in file-pages,
# which will have to be found in the data-page attribute of the li tag. .

def scrape_page_links(url, link_criteria):
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
        rows = soup.find_all(link_criteria)
        links = set(urljoin(url, row.find('a')['href']) for row in rows)
        return links
    except requests.RequestException as e:
        print(f"Error fetching the content: {e}")
        return set()
    except Exception as e:
        print(f"An error occurred: {e}")
        return set()

def scrape_autobiography_collection(url):
    return scrape_page_links(url, lambda tag: tag.name == 'li' and tag.find('a') and 'data-page' in tag.find('a').attrs
                                     and 'Illustration' not in tag.find('a')['href'])

def scrape_manuscript_pages(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
        
        rows = soup.find_all(lambda tag: tag.name == 'tr' and 'data-key' in tag.attrs and tag.find('td', string='Manuskripts'))
        manuscript_links = []
        for row in rows:
            link = row.find('a')['href']
            manuscript_links.append(urljoin('https://garamantas.lv', link))
        
        return set(manuscript_links)
    except requests.RequestException as e:
        print(f"Error fetching the content: {e}")
        return set()
    except Exception as e:
        print(f"An error occurred: {e}")
        return set()

def scrape_text_from_html(html):
    try:
        soup = BeautifulSoup(html, 'html.parser')
        
        tab_content_div = soup.find('div', class_='tab-content')
        
        if tab_content_div:
            tr_elements = tab_content_div.find_all('tr')
            
            pabeigts_found = any(tr.find('th', string='Pabeigts') and tr.find('td', string='Jā') for tr in tr_elements)
            parbaudits_found = any(tr.find('th', string='Pārbaudīts') and tr.find('td', string='Jā') for tr in tr_elements)
            
            if pabeigts_found and parbaudits_found:
                transcription_td = soup.find('td', class_='file-trascription-text')
                
                if transcription_td:
                    transcription_text = transcription_td.get_text(separator='\n').strip()
                    return transcription_text
                else:
                    return None
            else:
                return None
        else:
            print("Could not find the tab-content div.")
            return None
        
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# %%
import os
import pandas as pd

data_folder = 'Data'
corpus_folder = 'Data/Corpus'

# Create Data folder if it doesn't exist
if not os.path.exists(data_folder):
    os.makedirs(data_folder)

# Create Corpus folder if it doesn't exist
if not os.path.exists(corpus_folder):
    os.makedirs(corpus_folder)

# Define functions to save files in the respective folders
def save_to_corpus_folder(filename, content):
    filepath = os.path.join(corpus_folder, filename)
    with open(filepath, 'w', encoding='utf-8') as file:
        file.write(content)

def save_csv_to_data(filename, df):
    filepath = os.path.join(data_folder, filename)
    df.to_csv(filepath, index=False, encoding='utf-8-sig')

def get_file_name_from_url(url):
    url_sections = url.split('/')
    return '_'.join(url_sections[url_sections.index('collection')+1:])

def get_file_id_from_url(url):
    url_sections = url.split('/')
    return '_'.join(url_sections[url_sections.index('file')+1:])        

def save_txt_to_corpus(filename, texts):
    filepath = os.path.join(corpus_folder, filename)
    with open(filepath, 'w', encoding='utf-8') as file:
        for text in texts:
            file.write(text + '\n')

def scrape_and_save_texts(url, links):
    text_count = 0  # Variable to store the count of extracted texts
    manuscript_pages_count = 0  # Variable to store the count of manuscript pages extracted
    csv_filename = get_file_name_from_url(url) + '.csv'
    with open(os.path.join(data_folder, csv_filename), 'w', newline='', encoding='utf-8-sig') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['File-ID', 'Transcribed Text'])  # Write headers
        for link in links:
            manuscript_pages = scrape_manuscript_pages(link)
            manuscript_pages_count += len(manuscript_pages)  # Update total count of manuscript pages
            for manuscript_page in manuscript_pages:
                file_id = get_file_id_from_url(manuscript_page)
                text = scrape_text_from_html(requests.get(manuscript_page, timeout=20).content)
                if text:
                    writer.writerow([file_id, text])
                    text_count += 1  
    csv_to_txt(csv_filename)
    print(f"Total manuscript pages extracted: {manuscript_pages_count}")
    print(f"Total texts extracted: {text_count}")

def csv_to_txt(csv_file):
    df = pd.read_csv(os.path.join(data_folder, csv_file))
    texts = df['Transcribed Text']
    txt_filename = csv_file.replace('.csv', '.txt')
    if len(texts) > 0:
        try:
            save_txt_to_corpus(txt_filename, texts)
            print(f"Text file '{txt_filename}' successfully created.")
        except Exception as e:
            print(f"Failed to create text file '{txt_filename}': {e}")
    else:
        print(f"No transcribed and verified texts found. Text file '{txt_filename}' not created.")

# %%
# Load the first link from the diaries.csv file for testing purposes ignoring header

diaries_file = pd.read_csv('diaries.csv')
autobiography_collection_url =  diaries_file['Link'][0]
manuscript_hrefs = scrape_autobiography_collection(autobiography_collection_url)
scrape_and_save_texts(autobiography_collection_url, manuscript_hrefs)
# Out:
# Text file '1115688_Karla-Valguma-dienasgramatas.txt' successfully created.
#  Manuscript pages extracted:  20
# Texts extracted:  56

# %%
# If test is successful, the code can be run for all links in diaries.csv file, except the first one, as it has already been processed.

for link in diaries_file['Link'][1:]:
    manuscript_hrefs = scrape_autobiography_collection(link)
    scrape_and_save_texts(link, manuscript_hrefs)

# print the number of files in the corpus folder
print(f"Number of files in the corpus folder: {len(os.listdir(corpus_folder))}")
# Out:
# No transcribed and verified texts found. Text file '1115691_Ilzes-Spergas-skolas-dienasgramatas.txt' not created.
# Total manuscript pages extracted: 216
# Total texts extracted: 0
# Text file '1115696_Edgara-Reinsona-dienasgramata.txt' successfully created.
# Total manuscript pages extracted: 73
# Total texts extracted: 72
# No transcribed and verified texts found. Text file '1116161_Rutas-Luses-atminas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# Text file '1117599_Irmas-Viksninas-dienasgramata.txt' successfully created.
# Total manuscript pages extracted: 62
# Total texts extracted: 60
# Text file '1117599_nezinamas-rigas-skolnieces-dienasgramata.txt' successfully created.
# Total manuscript pages extracted: 62
# Total texts extracted: 60
# Text file '1117608_Dainas-Rozenblates-Atminu-zimejumi.txt' successfully created.
# Total manuscript pages extracted: 162
# Total texts extracted: 118
# Text file '1119253_Adama-Purmala-dzivesstasts.txt' successfully created.
# Total manuscript pages extracted: 182
# Total texts extracted: 143
# No transcribed and verified texts found. Text file '1119254_Emila-Pudela-dienasgramatas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# Text file '1119255_Nezinama-cilveka-dzivesstasts-Sakts-1944-g-augusta.txt' successfully created.
# Total manuscript pages extracted: 110
# Total texts extracted: 110
# Text file '1120355_Jana-Pavasara-dzivesstasts.txt' successfully created.
# Total manuscript pages extracted: 76
# Total texts extracted: 57
# No transcribed and verified texts found. Text file '1122602_Alidas-Arinas-dienasgramata.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# Text file '1122757_Kaspara-Tobja-dienasgramata.txt' successfully created.
# Total manuscript pages extracted: 101
# Total texts extracted: 2
# No transcribed and verified texts found. Text file '1132186_Maras-Graustinas-atminas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# Text file '1133883_Augusta-Heinrihsona-dzivesstasts.txt' successfully created.
# Total manuscript pages extracted: 20
# Total texts extracted: 1
# No transcribed and verified texts found. Text file '1134078_Erikas-Jurcas-dienasgramata.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1135449_Petera-Treimana-atminas.txt' not created.
# Total manuscript pages extracted: 67
# Total texts extracted: 0
# Text file '1135456_Dzintara-Lazera-atminas.txt' successfully created.
# Total manuscript pages extracted: 101
# Total texts extracted: 77
# Text file '1135459_Paula-Alksna-pieraksti-un-darba-zurnali.txt' successfully created.
# Total manuscript pages extracted: 210
# Total texts extracted: 1
# Text file '1135846_Nezinama-viriesa-dienasgramata-ar-nosaukumu-Daba.txt' successfully created.
# Total manuscript pages extracted: 58
# Total texts extracted: 1
# Text file '1135955_Astridas-Tobes-celojumu-dienasgramatas.txt' successfully created.
# Total manuscript pages extracted: 119
# Total texts extracted: 87
# No transcribed and verified texts found. Text file '1143205_Rutas-Smites-dienasgramata.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# Text file '1146801_Ulda-Kirsa-dzive-laukos-Tvitera-dienasgramata.txt' successfully created.
# Total manuscript pages extracted: 83
# Total texts extracted: 4
# Text file '1146882_Otto-Viksnas-atminas.txt' successfully created.
# Total manuscript pages extracted: 77
# Total texts extracted: 37
# No transcribed and verified texts found. Text file '1153249_Elizas-slepena-dienasgramata.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1163638_Viktora-dienasgramata.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1165277_Astras-Slezes-dienasgramata.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# Text file '1165988_Alvila-Kalniesa-Klebaha-dienasgramatas.txt' successfully created.
# Total manuscript pages extracted: 207
# Total texts extracted: 199
# No transcribed and verified texts found. Text file '1166033_Lizetes-Strautnieces-dienasgramata.txt' not created.
# Total manuscript pages extracted: 144
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1166034_Baibas-Ziles-dienasgramatas.txt' not created.
# Total manuscript pages extracted: 201
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1166035_Ainas-Rizgas-dzivesstasts.txt' not created.
# Total manuscript pages extracted: 24
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1169773_Alfreda-Baltbarza-dienasgramatas.txt' not created.
# Total manuscript pages extracted: 199
# Total texts extracted: 0
# Text file '1172699_Jana-Valtera-Cokas-atminas.txt' successfully created.
# Total manuscript pages extracted: 79
# Total texts extracted: 11
# Text file '1172883_Jana-Golvera-atminas.txt' successfully created.
# Total manuscript pages extracted: 60
# Total texts extracted: 45
# No transcribed and verified texts found. Text file '1173264_Gaidas-Mellupes-dienasgramatas-un-dzeja.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1174715_Paulines-Argales-dienasgramata.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1174752_Petera-Lucana-atminas.txt' not created.
# Total manuscript pages extracted: 154
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1176873_Vilmas-Heinrihsones-dienasgramata-un-atminas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1179135_Cezara-Aleksa-atminas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1179257_Jana-Auzenbaha-atminas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1179344_Lijas-Blumas-dienasgramata.txt' not created.
# Total manuscript pages extracted: 92
# Total texts extracted: 0
# Text file '1181543_Arvida-Feliksa-Latsona-dienasgramatas.txt' successfully created.
# Total manuscript pages extracted: 88
# Total texts extracted: 82
# No transcribed and verified texts found. Text file '1185814_Aleksandras-Eihes-dzivesstasts.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1185819_Elinas-piedzivojumi-Samara.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1185897_Erika-skolas-laika-dienasgramatas-1970-gados.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# Text file '1186759_Mirgas-Ivetas-Kulikovskas-dienasgramata.txt' successfully created.
# Total manuscript pages extracted: 68
# Total texts extracted: 17
# Text file '1186829_Veltas-Vitolas-atminas.txt' successfully created.
# Total manuscript pages extracted: 192
# Total texts extracted: 1
# No transcribed and verified texts found. Text file '1187224_Jura-Zarina-dienasgramatas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# Text file '1187225_Aleksandra-Kudina-atminas.txt' successfully created.
# Total manuscript pages extracted: 129
# Total texts extracted: 126
# Text file '1190402_Jekaba-Millera-atminas.txt' successfully created.
# Total manuscript pages extracted: 74
# Total texts extracted: 73
# No transcribed and verified texts found. Text file '1190647_Ulda-Pudela-atminas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# Text file '1192809_Karla-Kreicmana-atminas.txt' successfully created.
# Total manuscript pages extracted: 69
# Total texts extracted: 41
# Text file '1197004_Reisa-piezimes.txt' successfully created.
# Total manuscript pages extracted: 58
# Total texts extracted: 57
# No transcribed and verified texts found. Text file '1197727_Kaspara-Irbes-dienasgramatas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# Text file '1198781_Nezinama-viriesa-dienasgramata-no-1941-lidz-1942-gadam.txt' successfully created.
# Total manuscript pages extracted: 150
# Total texts extracted: 2
# No transcribed and verified texts found. Text file '1203198_Ziedones-Sermuksas-atminu-miniaturas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1203200_Lilijas-Auzenbahas-atminas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1205071_Vinetas-Beltinas-atminas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# Text file '1205557_Georga-Dimzes-atminas.txt' successfully created.
# Total manuscript pages extracted: 205
# Total texts extracted: 6
# Text file '1205720_Karla-Svensona-pieraksti.txt' successfully created.
# Total manuscript pages extracted: 204
# Total texts extracted: 2
# No transcribed and verified texts found. Text file '1206947_Margaretas-Grosvaldes-dienasgramata.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1206968_Emilijas-Vecvagares-dienasgramata.txt' not created.
# Total manuscript pages extracted: 87
# Total texts extracted: 0
# Text file '1207749_Valmieras-komercskolas-skolniecu-dienasgramata.txt' successfully created.
# Total manuscript pages extracted: 97
# Total texts extracted: 96
# Text file '1207861_Betijas-Gravas-dienasgramatas.txt' successfully created.
# Total manuscript pages extracted: 145
# Total texts extracted: 3
# No transcribed and verified texts found. Text file '1209370_Martina-Engizera-dienasgramatas-un-vestules.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1209459_Gunara-Viluma-dienasgramata.txt' not created.
# Total manuscript pages extracted: 80
# Total texts extracted: 0
# Text file '1209573_Balozu-gimenes-dienasgramata.txt' successfully created.
# Total manuscript pages extracted: 125
# Total texts extracted: 117
# No transcribed and verified texts found. Text file '1211235_Silvijas-Greninas-Priednieces-memuari.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# Text file '1214933_Celojums-pa-6-republikam-Dienasgramata.txt' successfully created.
# Total manuscript pages extracted: 37
# Total texts extracted: 2
# Text file '1217237_Artura-Kruma-pagatnes-enas.txt' successfully created.
# Total manuscript pages extracted: 139
# Total texts extracted: 11
# Text file '1217832_Andreja-Pablo-Mierkalna-dienasgramatas.txt' successfully created.
# Total manuscript pages extracted: 62
# Total texts extracted: 40
# Text file '1217962_Natalijas-Draudzinas-gimnazijas-skolniecu-dienasgramata.txt' successfully created.
# Total manuscript pages extracted: 169
# Total texts extracted: 4
# Text file '1222931_Jana-Davja-dzivesstasts.txt' successfully created.
# Total manuscript pages extracted: 200
# Total texts extracted: 185
# No transcribed and verified texts found. Text file '1238433_Anda-Mitana-atminas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# Text file '1238885_Arija-Vilemsona-raksti.txt' successfully created.
# Total manuscript pages extracted: 106
# Total texts extracted: 42
# Text file '1245358_R-Abolina-dienasgramata.txt' successfully created.
# Total manuscript pages extracted: 45
# Total texts extracted: 2
# No transcribed and verified texts found. Text file '1246190_Telnieka-Jana-Zibens-dienasgramata.txt' not created.
# Total manuscript pages extracted: 50
# Total texts extracted: 0
# Text file '1246844_Anda-Mitana-un-Gunara-Skubina-sarakste.txt' successfully created.
# Total manuscript pages extracted: 201
# Total texts extracted: 112
# Text file '1247269_Alfreda-Krumina-dienasgramatas.txt' successfully created.
# Total manuscript pages extracted: 220
# Total texts extracted: 1
# No transcribed and verified texts found. Text file '1247341_Mecislava-Vertinska-atminas-Vospominaniya-Mitchislava-Vertinskogo.txt' not created.
# Total manuscript pages extracted: 43
# Total texts extracted: 0
# Text file '1247401_Annas-Vagales-atminas.txt' successfully created.
# Total manuscript pages extracted: 28
# Total texts extracted: 1
# Text file '1261070_Nikolaja-Brivlauka-atminas.txt' successfully created.
# Total manuscript pages extracted: 35
# Total texts extracted: 35
# Text file '1268074_Veltas-Sproges-dienasgramata.txt' successfully created.
# Total manuscript pages extracted: 201
# Total texts extracted: 197
# Text file '1270711_Jana-Sudmala-dienasgramatas.txt' successfully created.
# Total manuscript pages extracted: 215
# Total texts extracted: 201
# No transcribed and verified texts found. Text file '1270836_Laimona-Upmala-atminas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1276648_Annas-Koch-dienasgramata.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# Text file '1276664_Dienasgramata-Vecsetu-muizas-kases-gramata.txt' successfully created.
# Total manuscript pages extracted: 45
# Total texts extracted: 1
# Text file '1277288_Imanta-Freimana-dienasgramatas.txt' successfully created.
# Total manuscript pages extracted: 207
# Total texts extracted: 206
# No transcribed and verified texts found. Text file '1282797_Jana-Springa-dienasgramatas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1282975_Mikela-Pankoka-dienasgramata.txt' not created.
# Total manuscript pages extracted: 154
# Total texts extracted: 0
# Text file '1283130_Petera-Smita-autobiografija.txt' successfully created.
# Total manuscript pages extracted: 91
# Total texts extracted: 91
# No transcribed and verified texts found. Text file '1283650_Nezinama-cilveka-no-1918-lidz-1919-gadam-rakstita-dienasgramata.txt' not created.
# Total manuscript pages extracted: 78
# Total texts extracted: 0
# Text file '1283651_Zana-Talberga-Kolimas-dienasgramata.txt' successfully created.
# Total manuscript pages extracted: 31
# Total texts extracted: 25
# Text file '1284358_Silvijas-Gruntes-autobiografiskie-materiali.txt' successfully created.
# Total manuscript pages extracted: 209
# Total texts extracted: 2
# No transcribed and verified texts found. Text file '1285537_Paula-Alksna-dienasgramatas.txt' not created.
# Total manuscript pages extracted: 69
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1289462_Omes-stasti.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# Text file '1290580_Voldemara-Mitenieka-dzivesstasts.txt' successfully created.
# Total manuscript pages extracted: 101
# Total texts extracted: 101
# No transcribed and verified texts found. Text file '1290778_Ellas-Kreicmanes-atminas-par-dzimtu.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1290779_Nadinas-Pavlovas-atminas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1291616_Martas-Vitumas-atminu-stasti.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# Text file '1293854_Imanta-Jansona-dienasgramata.txt' successfully created.
# Total manuscript pages extracted: 115
# Total texts extracted: 109
# No transcribed and verified texts found. Text file '1294077_Egona-Talivalza-Ziedina-dienasgramatas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1295128_Jekaba-Ziedara-atminas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# Text file '1297628_Mikela-Tupesa-dienasgramatas.txt' successfully created.
# Total manuscript pages extracted: 206
# Total texts extracted: 162
# Text file '1306961_Hertas-Egles-dzivesstasts.txt' successfully created.
# Total manuscript pages extracted: 23
# Total texts extracted: 23
# Text file '1307228_Romana-Duna-atminas.txt' successfully created.
# Total manuscript pages extracted: 97
# Total texts extracted: 97
# Text file '1307411_Adolfa-Cerbikova-dzivesstasts.txt' successfully created.
# Total manuscript pages extracted: 90
# Total texts extracted: 75
# No transcribed and verified texts found. Text file '1307590_Alberta-Balttura-dienasgramatas-Dnevniki-Alberta-Balttura.txt' not created.
# Total manuscript pages extracted: 154
# Total texts extracted: 0
# Text file '1307973_Elizabetes-Busas-atminas-un-dzeja.txt' successfully created.
# Total manuscript pages extracted: 66
# Total texts extracted: 50
# Text file '1311692_Kapteina-P-Zolta-skautu-saimes-dienasgramata.txt' successfully created.
# Total manuscript pages extracted: 142
# Total texts extracted: 141
# No transcribed and verified texts found. Text file '1311836_Aivara-Puzula-atminas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1312670_Veltas-Zvanitajas-atminas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1312671_Mariannas-Vecaines-atminas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1312672_Ninas-Ozolinas-dienasgramata-un-atminas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1312673_Jana-Pirtnieka-atminas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1312675_Antoninas-Braslas-atminas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1312679_Izvilkumi-no-Viestura-un-Innas-iszinu-sarakstes.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1312680_Annas-Milleres-atminas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1312682_Karla-Zemdegas-dienasgramata.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1312683_Spodras-Ozolinas-dienasgramata.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1312685_Zaigas-Zandmanes-atminu-stasti.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1312687_Roberta-Ligera-un-Rigas-pantomimas-dienasgramatas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1312689_Jura-Emsina-atminas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# Text file '1312690_Aijas-Viksnas-atminas.txt' successfully created.
# Total manuscript pages extracted: 36
# Total texts extracted: 35
# No transcribed and verified texts found. Text file '1313132_Olgas-Rasas-atminas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# Text file '1313134_Edmunda-Ozolina-dzivesstasts.txt' successfully created.
# Total manuscript pages extracted: 95
# Total texts extracted: 93
# Text file '1313135_Lukasa-Ozolina-atminas.txt' successfully created.
# Total manuscript pages extracted: 197
# Total texts extracted: 46
# Text file '1313137_Vladimira-Vigdorcika-atminas.txt' successfully created.
# Total manuscript pages extracted: 133
# Total texts extracted: 2
# Text file '1315594_Zigfrida-Karla-Brakmana-atminas.txt' successfully created.
# Total manuscript pages extracted: 61
# Total texts extracted: 17
# No transcribed and verified texts found. Text file '1328742_Petera-Stepina-atminas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1336271_Emila-Kriskana-dzivesstasts.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1336311_Marfas-Mivrenikas-atminas-Vospominaniya-Marfy-Mivrenik.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1341745_Jevgenija-Siksnana-dienasgramatas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1345338_Nikolaja-Ulmana-atminas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1352592_Edgara-Ezerlicisa-atminas.txt' not created.
# Total manuscript pages extracted: 212
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1360382_Genovefas-Upenieces-dienasgramatas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1361216_Ozolaines-skolas-pionieru-pulcina-dienasgramata.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# Text file '1362666_Davja-Dauvarta-dienasgramata.txt' successfully created.
# Total manuscript pages extracted: 88
# Total texts extracted: 83
# Text file '1367125_Vijas-Polakas-dzivesstasts.txt' successfully created.
# Total manuscript pages extracted: 40
# Total texts extracted: 1
# No transcribed and verified texts found. Text file '1372230_Bronislavas-dienasgramatas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# Text file '1375693_Zigridas-Paegles-dienasgramatas.txt' successfully created.
# Total manuscript pages extracted: 188
# Total texts extracted: 21
# Text file '1376071_Laimona-Upmala-dienasgramata.txt' successfully created.
# Total manuscript pages extracted: 98
# Total texts extracted: 76
# No transcribed and verified texts found. Text file '1378689_Zigridas-Paegles-un-Marijas-Liepnieces-pieraksti.txt' not created.
# Total manuscript pages extracted: 70
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1378773_Daces-Skeranskas-dienasgramatas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1379002_Jazepa-Puksta-dienasgramata.txt' not created.
# Total manuscript pages extracted: 64
# Total texts extracted: 0
# Text file '1386157_Karla-Lapina-dienasgramata.txt' successfully created.
# Total manuscript pages extracted: 34
# Total texts extracted: 19
# No transcribed and verified texts found. Text file '1386177_Benitas-Neimanes-dienasgramatas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1388011_Vitas-Neimanes-kalendari.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# Text file '1388227_Eduarda-Smurga-atminas.txt' successfully created.
# Total manuscript pages extracted: 220
# Total texts extracted: 47
# No transcribed and verified texts found. Text file '1393069_Nezinama-strelnieka-dienasgramata.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1393308_L-Zalisa-un-B-Strada-skautu-dienasgramata.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1410746_Eduarda-Tancera-vestules.txt' not created.
# Total manuscript pages extracted: 26
# Total texts extracted: 0
# Text file '1410773_Jana-Tancera-vestules-un-atminas.txt' successfully created.
# Total manuscript pages extracted: 141
# Total texts extracted: 14
# Text file '1410929_Ligitas-Vucenas-dienasgramatas.txt' successfully created.
# Total manuscript pages extracted: 245
# Total texts extracted: 245
# No transcribed and verified texts found. Text file '1414449_Raimonda-Dusela-atminas-par-Kolimas-darba-nometni.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1415829_Pandemijas-dienasgramatas-2020-2021.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1422036_Alberta-Losana-vestules.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1438382_Linas-Zalites-dienasgramata.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1448573_Jana-Rudzana-vestule.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1450102_Stasti-par-pieredzeto-vardarbibu.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1451221_Veronikas-Vitolas-atminas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# Text file '1458840_Karla-Alberta-Sila-dienasgramata.txt' successfully created.
# Total manuscript pages extracted: 108
# Total texts extracted: 104
# Text file '1465160_Petera-Pokrotnieka-dienasgramata.txt' successfully created.
# Total manuscript pages extracted: 80
# Total texts extracted: 4
# No transcribed and verified texts found. Text file '1465502_Laumas-Silis-atminas-par-dzimtu.txt' not created.
# Total manuscript pages extracted: 114
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1475240_L-G-C-O-65-pulcina-parzines-dienasgramata.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# Text file '1475487_Eustahijas-Lucjanovas-dienasgramata.txt' successfully created.
# Total manuscript pages extracted: 81
# Total texts extracted: 80
# No transcribed and verified texts found. Text file '1483886_Viktora-Medena-atminas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1501853_Valentina-Purina-atminas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1502631_Dzidras-Bukaines-atminas-un-dienasgramata.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# Text file '1510251_Elmas-Marijas-Vanags-dienasgramata.txt' successfully created.
# Total manuscript pages extracted: 56
# Total texts extracted: 54
# No transcribed and verified texts found. Text file '1529456_Jana-Cikota-dienasgramata.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1532640_Edgara-un-Austras-Liepinu-sarakste.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# Text file '1540385_Petera-Zarina-atminas.txt' successfully created.
# Total manuscript pages extracted: 191
# Total texts extracted: 190
# Text file '1543863_Skaidrites-Rozites-atminas.txt' successfully created.
# Total manuscript pages extracted: 12
# Total texts extracted: 2
# No transcribed and verified texts found. Text file '1550804_Austras-Rudzites-dienasgramatas-un-vestules.txt' not created.
# Total manuscript pages extracted: 206
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1550805_Arnolda-Apses-dienasgramatas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# Text file '1564964_Ernesta-Slaucitaja-dienasgramata.txt' successfully created.
# Total manuscript pages extracted: 79
# Total texts extracted: 7
# No transcribed and verified texts found. Text file '1581242_Zentas-Laimdotas-Liepaskalns-dienasgramata.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1587294_Pavila-Svabes-atminas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1589654_Sulcu-dzimtas-korespondence.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1589746_Veras-Goppers-atminas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# Text file '1593461_F-Celmina-dienasgramata.txt' successfully created.
# Total manuscript pages extracted: 151
# Total texts extracted: 32
# No transcribed and verified texts found. Text file '1595515_Karla-Daukstes-atminas.txt' not created.
# Total manuscript pages extracted: 97
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1595518_Alfreda-Teodora-Zigura-atminas.txt' not created.
# Total manuscript pages extracted: 131
# Total texts extracted: 0
# Text file '1633500_Marijas-Berzinas-atminas.txt' successfully created.
# Total manuscript pages extracted: 202
# Total texts extracted: 199
# No transcribed and verified texts found. Text file '1636545_Ligitas-Vucenas-atminas-par-Peteri-Upiti.txt' not created.
# Total manuscript pages extracted: 189
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1636812_Gunara-Dambes-celojuma-dienasgramata-un-vestules.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# Text file '1636933_Jana-Grinvalda-dienasgramatas.txt' successfully created.
# Total manuscript pages extracted: 219
# Total texts extracted: 5
# Text file '1636935_Ainas-Zepas-dienasgramata.txt' successfully created.
# Total manuscript pages extracted: 21
# Total texts extracted: 1
# Text file '1636959_Rutas-Sleieres-dienasgramatas.txt' successfully created.
# Total manuscript pages extracted: 160
# Total texts extracted: 160
# No transcribed and verified texts found. Text file '1644074_Martas-Kapinas-dienasgramata.txt' not created.
# Total manuscript pages extracted: 216
# Total texts extracted: 0
# Text file '1646639_Jana-Grinvalda-dienasgramata-par-Daini.txt' successfully created.
# Total manuscript pages extracted: 215
# Total texts extracted: 25
# Text file '1648999_Luizes-Griganes-dienasgramata.txt' successfully created.
# Total manuscript pages extracted: 207
# Total texts extracted: 198
# Text file '1652337_Edgara-un-Mirdzas-Laku-dienasgramatas.txt' successfully created.
# Total manuscript pages extracted: 214
# Total texts extracted: 83
# No transcribed and verified texts found. Text file '1662229_Alfreda-Skeles-dienasgramata-un-atminas.txt' not created.
# Total manuscript pages extracted: 83
# Total texts extracted: 0
# Text file '1687233_Almas-Vucenas-atminas.txt' successfully created.
# Total manuscript pages extracted: 209
# Total texts extracted: 205
# Text file '1689269_Vestules-aktrisei-Malvinei-Ustubei.txt' successfully created.
# Total manuscript pages extracted: 146
# Total texts extracted: 33
# Text file '1689421_Alidas-Kigules-vestules.txt' successfully created.
# Total manuscript pages extracted: 35
# Total texts extracted: 1
# Text file '1690857_Valda-Skeles-atminas.txt' successfully created.
# Total manuscript pages extracted: 61
# Total texts extracted: 1
# No transcribed and verified texts found. Text file '1695006_Gunara-Ozolina-dienasgramata.txt' not created.
# Total manuscript pages extracted: 32
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1742058_Ainas-Eglites-dienasgramatas.txt' not created.
# Total manuscript pages extracted: 218
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1778010_Zelmas-Indriksones-autobiografiskie-materiali.txt' not created.
# Total manuscript pages extracted: 176
# Total texts extracted: 0
# Text file '1797583_Karla-Sabaka-atminas.txt' successfully created.
# Total manuscript pages extracted: 73
# Total texts extracted: 4
# Text file '1799971_Izraksti-no-Karla-Paucisa-dienasgramatam.txt' successfully created.
# Total manuscript pages extracted: 209
# Total texts extracted: 23
# No transcribed and verified texts found. Text file '1808511_Adolfa-Zinga-atminas.txt' not created.
# Total manuscript pages extracted: 75
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1812166_Bronislavas-Berzinas-dzimtas-atminas-un-Annas-Apsas-dziesma.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1813845_Maijas-dienasgramatas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1822798_Arnolda-Zervena-dienasgramata.txt' not created.
# Total manuscript pages extracted: 23
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1843219_Ilgvara-Ozola-dienasgramatas.txt' not created.
# Total manuscript pages extracted: 11
# Total texts extracted: 0
# Text file '1846318_Katrines-Butenieces-dienasgramata-no-1904-lidz-1924-gadam.txt' successfully created.
# Total manuscript pages extracted: 205
# Total texts extracted: 196
# No transcribed and verified texts found. Text file '1846685_Indrika-Ritina-dzivesstasts.txt' not created.
# Total manuscript pages extracted: 77
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1846915_Jura-Viksnas-dzimtas-petijums.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1866763_Julija-Celmina-dienasgramatas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1896598_Petera-Rubina-atminas.txt' not created.
# Total manuscript pages extracted: 118
# Total texts extracted: 0
# Text file '1900122_Karla-Vesmana-vestules-un-Annas-Rosmanes-dzivesstasts.txt' successfully created.
# Total manuscript pages extracted: 175
# Total texts extracted: 100
# Text file '1910061_Olgas-Veges-atminas.txt' successfully created.
# Total manuscript pages extracted: 130
# Total texts extracted: 1
# No transcribed and verified texts found. Text file '1910639_Gunara-Indriksona-dienasgramatas.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1910641_Mildas-Laubertes-dienasgramata.txt' not created.
# Total manuscript pages extracted: 123
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1910644_Antona-Grinberga-dienasgramata.txt' not created.
# Total manuscript pages extracted: 0
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1937748_Latviesu-karaviru-likteni.txt' not created.
# Total manuscript pages extracted: 186
# Total texts extracted: 0
# No transcribed and verified texts found. Text file '1946321_Beates-Skinkis-dienasgramata.txt' not created.
# Total manuscript pages extracted: 158
# Total texts extracted: 0
# Number of files in the corpus folder: 95
